# %%
from src.data import make_data, save_data, load_data

# %%
data = make_data()

# %%
# data

# %%
save_data(data, 'test_data.npy')

# %%
data2 = load_data('test_data.npy')
data2
# Out:
# array([[20,  4],
#        [10, 16],
#        [14,  1],
#        [23,  7],
#        [16, 10],
#        [23, 22],
#        [ 4, 22],
#        [ 7,  5],
#        [ 9, 13],
#        [14,  4],
#        [11, 14],
#        [ 1, 16],
#        [ 9, 10],
#        [ 3, 10],
#        [16,  8],
#        [10, 20],
#        [17, 12],
#        [ 7,  8],
#        [ 5,  6],
#        [ 6, 14],
#        [11,  4],
#        [14,  6],
#        [ 1, 20],
#        [ 0,  7],
#        [23, 20],
#        [11,  7],
#        [ 5, 11],
#        [ 5, 11],
#        [ 7,  0],
#        [20, 12],
#        [13, 17],
#        [ 1, 18],
#        [17, 14],
#        [ 4,  8],
#        [20, 23],
#        [ 7,  6],
#        [10, 16],
#        [18, 18],
#        [ 3, 23],
#        [13, 22],
#        [ 0,  0],
#        [ 4, 23],
#        [14, 22],
#        [12, 17],
#        [ 2, 18],
#        [17, 10],
#        [22,  6],
#        [ 7,  2],
#        [12,  3],
#        [22,  8],
#        [15,  8],
#        [10, 10],
# ...
