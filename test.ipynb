# %%
from src.data import make_data, save_data, load_data

# %%
data = make_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 data = make_data()
#
# File ~/Desktop/WM/S26/AW/data440-s26/src/data.py:12, in make_data(n, low, high)
#       8 def make_data (n: int = 100, low: int = 0, high: int = 24) -> np.array:
#       9     '''
#      10     Return an nx2 array of random integers between low and high (inclusive)
#      11     '''
# ---> 12     return np.random.randomint(low = low, high = high, size = (n, 2))
#
# AttributeError: module 'numpy.random' has no attribute 'randomint'
